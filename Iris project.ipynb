# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# Display the first few rows
print(iris.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## 1. Data Import and Exploration ##
#
# Explore the Dataset Structure:

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Display a summary of the dataset
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## 2.Data Visualization ##

# %%
#Scatterplot
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
sns.scatterplot(x="sepal_length", y="sepal_width", data= iris, hue="species", ax=axes[0])
axes[0].set_title('Correlation BTW Sepal Length and Sepal Width by Species')
sns.scatterplot(x="petal_length", y="petal_width", data= iris, hue="species", ax=axes[1])
axes[1].set_title('Correlation BTW Petal Length and Petal Width by Species')
# Out:
# Text(0.5, 1.0, 'Correlation BTW Petal Length and Petal Width by Species')

# %%
import matplotlib.pyplot as plt
#Boxplots for Feature Distributions
# Create a 2x2 grid for subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))  # Adjust the figure size as needed

# Create box plots for each feature
sns.boxplot(x='species', y='sepal_length', data=iris, ax=axes[0, 0])
axes[0, 0].set_title('Sepal Length by Species')

sns.boxplot(x='species', y='sepal_width', data=iris, ax=axes[0, 1])
axes[0, 1].set_title('Sepal Width by Species')

sns.boxplot(x='species', y='petal_length', data=iris, ax=axes[1, 0])
axes[1, 0].set_title('Petal Length by Species')

sns.boxplot(x='species', y='petal_width', data=iris, ax=axes[1, 1])
axes[1, 1].set_title('Petal Width by Species')

# Adjust the layout for better spacing
plt.tight_layout()
plt.show()

# %%
#Histograms for Numerical Variables
iris.hist(figsize=(10, 8), bins=15, color='lightblue')
plt.suptitle('Histograms of Numerical Features')
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))  # Width of 12 and height of 10

# Plot density plots in each subplot
sns.kdeplot(data=iris, x='sepal_length', hue='species', fill=True, alpha=0.5, ax=axes[0, 0])
axes[0, 0].set_title('Sepal Length Density')

sns.kdeplot(data=iris, x='sepal_width', hue='species', fill=True, alpha=0.5, ax=axes[0, 1])
axes[0, 1].set_title('Sepal Width Density')

sns.kdeplot(data=iris, x='petal_length', hue='species', fill=True, alpha=0.5, ax=axes[1, 0])
axes[1, 0].set_title('Petal Length Density')

sns.kdeplot(data=iris, x='petal_width', hue='species', fill=True, alpha=0.5, ax=axes[1, 1])
axes[1, 1].set_title('Petal Width Density')

# Adjust the layout to avoid overlapping titles and labels
plt.tight_layout()
plt.show()
# Out:
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# ## 3. Statistical Summary and Insights ##

# %%
#Calculate Basic Statistics
for feature in ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']:
    mean_feature= iris[feature].mean()
    print(f"mean of {feature}:{mean_feature}")
# Out:
# mean of sepal_length:5.843333333333334
# mean of sepal_width:3.0573333333333337
# mean of petal_length:3.7580000000000005
# mean of petal_width:1.1993333333333336

# %%
for feature in ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']:
    median_feature= iris[feature].median()
    print(f"median of {feature}:{median_feature}")
# Out:
# median of sepal_length:5.8
# median of sepal_width:3.0
# median of petal_length:4.35
# median of petal_width:1.3

# %%
for feature in ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']:
    std_feature= iris[feature].std()
    print(f"Standard Deviation of {feature}:{std_feature}")
# Out:
# Standard Deviation of sepal_length:0.8280661279778629
# Standard Deviation of sepal_width:0.435866284936698
# Standard Deviation of petal_length:1.7652982332594667
# Standard Deviation of petal_width:0.7622376689603465

# %%
conda install conda-forge::scikit-learn
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.9.2

# %% [markdown]
# ## 4.Simple Classification Model

# %%
# Split the Dataset
from sklearn.model_selection import train_test_split

X = iris.drop(columns='species')
y = iris['species']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#Evaluate the Model
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Instantiate the k-NN model
knn = KNeighborsClassifier(n_neighbors=3)

# Fit the model to the training data
knn.fit(X_train, y_train)

# Predict on the test set
y_pred = knn.predict(X_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Display the confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

# Detailed classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.00
# Confusion Matrix:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
